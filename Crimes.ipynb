# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %%
# Path to the dataset
dataset_path = './Data/Map-Crime_Incidents-Previous_Three_Months.csv'
# Read the dataset into a DataFrame
SF = pd.read_csv(dataset_path)

# %%
# Display the first 5 rows of the DataFrame
SF.head(5)
# Out:
#    IncidntNum       Category                        Descript DayOfWeek  \
# 0         NaN  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1         NaN  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2         NaN  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3         NaN  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4         NaN  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  \
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974
# ...

# %%
# Display the last 5 rows of the DataFrame
SF.tail(5)
# Out:
#        IncidntNum        Category                               Descript  \
# 30755         NaN   LARCENY/THEFT                PETTY THEFT SHOPLIFTING
# 30756         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 30757         NaN         ASSAULT                                BATTERY
# 30758         NaN         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS
# 30759         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
#       DayOfWeek                          Date   Time  PdDistrict  \
# 30755    Sunday  06/01/2014 07:00:00 AM +0000  15:30    SOUTHERN
# 30756    Sunday  06/01/2014 07:00:00 AM +0000  16:00    NORTHERN
# 30757    Sunday  06/01/2014 07:00:00 AM +0000  15:00  TENDERLOIN
# 30758    Sunday  06/01/2014 07:00:00 AM +0000  15:20     CENTRAL
# 30759    Sunday  06/01/2014 07:00:00 AM +0000  13:15   INGLESIDE
#
#            Resolution                   Address           X          Y  \
# ...

# %%
# Display the entire DataFrame
SF
# Out:
#        IncidntNum        Category                               Descript  \
# 0             NaN   LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO
# 1             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 2             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 3             NaN   DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE
# 4             NaN   DRUG/NARCOTIC                  POSSESSION OF COCAINE
# ...           ...             ...                                    ...
# 30755         NaN   LARCENY/THEFT                PETTY THEFT SHOPLIFTING
# 30756         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 30757         NaN         ASSAULT                                BATTERY
# 30758         NaN         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS
# 30759         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
#       DayOfWeek                          Date   Time  PdDistrict  \
# ...

# %%
# Get the shape of the DataFrame (rows, columns)
SF.shape
# Out:
# (30760, 12)

# %%
# Set the maximum number of rows to display
pd.set_option('display.max_rows', 10)
# Display the DataFrame again
SF
# Out:
#        IncidntNum        Category                               Descript  \
# 0             NaN   LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO
# 1             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 2             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 3             NaN   DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE
# 4             NaN   DRUG/NARCOTIC                  POSSESSION OF COCAINE
# ...           ...             ...                                    ...
# 30755         NaN   LARCENY/THEFT                PETTY THEFT SHOPLIFTING
# 30756         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 30757         NaN         ASSAULT                                BATTERY
# 30758         NaN         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS
# 30759         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
#       DayOfWeek                          Date   Time  PdDistrict  \
# ...

# %%
# Get the column names of the DataFrame
SF.columns
# Out:
# Index(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time',
#        'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location'],
#       dtype='object')

# %%
# Get the number of rows in the DataFrame
len(SF)
# Out:
# 30760

# %%
# Get the data types of each column in the DataFrame
SF.dtypes
# Out:
# IncidntNum    float64
# Category       object
# Descript       object
# DayOfWeek      object
# Date           object
#                ...
# Resolution     object
# Address        object
# X             float64
# Y             float64
# Location       object
# Length: 12, dtype: object

# %%
# Display the DataFrame again
SF
# Out:
#        IncidntNum        Category                               Descript  \
# 0             NaN   LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO
# 1             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 2             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 3             NaN   DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE
# 4             NaN   DRUG/NARCOTIC                  POSSESSION OF COCAINE
# ...           ...             ...                                    ...
# 30755         NaN   LARCENY/THEFT                PETTY THEFT SHOPLIFTING
# 30756         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 30757         NaN         ASSAULT                                BATTERY
# 30758         NaN         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS
# 30759         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
#       DayOfWeek                          Date   Time  PdDistrict  \
# ...

# %%
# Extract the 'Date' column from the DataFrame
SF['Date']
# Out:
# 0        08/31/2014 07:00:00 AM +0000
# 1        08/31/2014 07:00:00 AM +0000
# 2        08/31/2014 07:00:00 AM +0000
# 3        08/31/2014 07:00:00 AM +0000
# 4        08/31/2014 07:00:00 AM +0000
#                      ...
# 30755    06/01/2014 07:00:00 AM +0000
# 30756    06/01/2014 07:00:00 AM +0000
# 30757    06/01/2014 07:00:00 AM +0000
# 30758    06/01/2014 07:00:00 AM +0000
# 30759    06/01/2014 07:00:00 AM +0000
# Name: Date, Length: 30760, dtype: object

# %%
# Check the data type of the first element in the 'Date' column
type(SF['Date'][0])
# Out:
# str

# %%
# Extract month and day from the 'Date' column and create new columns for them
SF['Month'] = SF['Date'].apply(lambda row: int(row[0:2]))
SF['Day'] = SF['Date'].apply(lambda row: int(row[3:5]))
# Display the DataFrame with new 'Month' and 'Day' columns
SF
# Out:
#        IncidntNum        Category                               Descript  \
# 0             NaN   LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO
# 1             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 2             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 3             NaN   DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE
# 4             NaN   DRUG/NARCOTIC                  POSSESSION OF COCAINE
# ...           ...             ...                                    ...
# 30755         NaN   LARCENY/THEFT                PETTY THEFT SHOPLIFTING
# 30756         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 30757         NaN         ASSAULT                                BATTERY
# 30758         NaN         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS
# 30759         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
#       DayOfWeek                          Date   Time  PdDistrict  \
# ...

# %%
# Print the first two elements of the 'Month' and 'Day' columns
print(SF['Month'][0:2])
print(SF['Day'][0:2])
# Out:
# 0    8
# 1    8
# Name: Month, dtype: int64
# 0    31
# 1    31
# Name: Day, dtype: int64

# %%
# Check the data type of the first element in the 'Month' column
print(type(SF['Month'][0]))
# Out:
# <class 'numpy.int64'>

# %%
# Delete unnecessary columns from the DataFrame
del SF['IncidntNum']

# %%
# Delete unnecessary columns from the DataFrame
SF.drop('Location', axis=1, inplace=True )

# %%
# Display the DataFrame again
SF
# Out:
#              Category                               Descript DayOfWeek  \
# 0       LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1       LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO    Sunday
# 2       LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO    Sunday
# 3       DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE    Sunday
# 4       DRUG/NARCOTIC                  POSSESSION OF COCAINE    Sunday
# ...               ...                                    ...       ...
# 30755   LARCENY/THEFT                PETTY THEFT SHOPLIFTING    Sunday
# 30756  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED    Sunday
# 30757         ASSAULT                                BATTERY    Sunday
# 30758         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS    Sunday
# 30759  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED    Sunday
#
#                                Date   Time  PdDistrict      Resolution  \
# ...

# %%
# Get the updated column names of the DataFrame
SF.columns
# Out:
# Index(['Category', 'Descript', 'DayOfWeek', 'Date', 'Time', 'PdDistrict',
#        'Resolution', 'Address', 'X', 'Y', 'Month', 'Day'],
#       dtype='object')

# %%
# Count the occurrences of each category in the 'Category' column
CountCategory = SF['Category'].value_counts()
print(CountCategory)
# Out:
# LARCENY/THEFT                 8205
# OTHER OFFENSES                4004
# NON-CRIMINAL                  3653
# ASSAULT                       2518
# VEHICLE THEFT                 1885
#                               ...
# SEX OFFENSES, NON FORCIBLE       5
# BAD CHECKS                       3
# GAMBLING                         1
# PORNOGRAPHY/OBSCENE MAT          1
# BRIBERY                          1
# Name: Category, Length: 36, dtype: int64

# %%
# Count the occurrences of each category in the 'Category' column in ascending order
SF['Category'].value_counts(ascending=True)
# Out:
# PORNOGRAPHY/OBSCENE MAT          1
# GAMBLING                         1
# BRIBERY                          1
# BAD CHECKS                       3
# SEX OFFENSES, NON FORCIBLE       5
#                               ...
# VEHICLE THEFT                 1885
# ASSAULT                       2518
# NON-CRIMINAL                  3653
# OTHER OFFENSES                4004
# LARCENY/THEFT                 8205
# Name: Category, Length: 36, dtype: int64

# %%
# Count the occurrences of each category in the 'Category' column in ascending order
print(SF['Category'].value_counts(ascending=True))
# Out:
# PORNOGRAPHY/OBSCENE MAT          1
# GAMBLING                         1
# BRIBERY                          1
# BAD CHECKS                       3
# SEX OFFENSES, NON FORCIBLE       5
#                               ...
# VEHICLE THEFT                 1885
# ASSAULT                       2518
# NON-CRIMINAL                  3653
# OTHER OFFENSES                4004
# LARCENY/THEFT                 8205
# Name: Category, Length: 36, dtype: int64

# %%
# Print the occurrences of each district in the 'PdDistrict' column in ascending order
print(SF['PdDistrict'].value_counts(ascending=True))
# Out:
# RICHMOND      1622
# PARK          1800
# TARAVAL       2038
# TENDERLOIN    2449
# INGLESIDE     2613
# BAYVIEW       2970
# NORTHERN      3205
# CENTRAL       3867
# MISSION       4011
# SOUTHERN      6185
# Name: PdDistrict, dtype: int64

# %%
# Filter the DataFrame to include only crimes that occurred in August
AugustCrimes = SF[SF['Month'] == 8]
AugustCrimes
# Out:
#                          Category  \
# 0                   LARCENY/THEFT
# 1                   LARCENY/THEFT
# 2                   LARCENY/THEFT
# 3                   DRUG/NARCOTIC
# 4                   DRUG/NARCOTIC
# ...                           ...
# 9715                 NON-CRIMINAL
# 9716               OTHER OFFENSES
# 9717                      ASSAULT
# 9718  DRIVING UNDER THE INFLUENCE
# 9719       SEX OFFENSES, FORCIBLE
#
#                                           Descript DayOfWeek  \
# 0                   GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1                     GRAND THEFT FROM LOCKED AUTO    Sunday
# 2                     GRAND THEFT FROM LOCKED AUTO    Sunday
# 3                   POSSESSION OF METH-AMPHETAMINE    Sunday
# 4                            POSSESSION OF COCAINE    Sunday
# ...                                            ...       ...
# 9715                  AIDED CASE, MENTAL DISTURBED    Friday
# ...

# %%
# Filter the DataFrame to include only burglaries that occurred in August
AugustCrimes = SF[SF['Month'] == 8]
AugustCrimesB = SF[SF['Category'] == 'BURGLARY']
len(AugustCrimesB)
# Out:
# 1257

# %%
# Filter the DataFrame to include crimes that occurred on July 4th
Crime0704 = SF.query('Month == 7 and Day == 4')
Crime0704
# Out:
#              Category                                          Descript  \
# 19087   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19088   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19089        BURGLARY  BURGLARY,RESIDENCE UNDER CONSTRT, FORCIBLE ENTRY
# 19090    NON-CRIMINAL                                     LOST PROPERTY
# 19091         ASSAULT                                           BATTERY
# ...               ...                                               ...
# 19423   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19424  OTHER OFFENSES                         LOST/STOLEN LICENSE PLATE
# 19425   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19426   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19427   LARCENY/THEFT                           PETTY THEFT OF PROPERTY
#
#       DayOfWeek                          Date   Time PdDistrict Resolution  \
# ...

# %%
# Get the column names of the DataFrame
SF.columns
# Out:
# Index(['Category', 'Descript', 'DayOfWeek', 'Date', 'Time', 'PdDistrict',
#        'Resolution', 'Address', 'X', 'Y', 'Month', 'Day'],
#       dtype='object')

# %%
# Create a scatter plot of crime incidents using longitude and latitude coordinates
plt.plot(SF['X'],SF['Y'], 'ro')
plt.show()

# %%
# Get unique police districts from the 'PdDistrict' column
pd_districts = np.unique(SF['PdDistrict'])
pd_districts
# Out:
# array(['BAYVIEW', 'CENTRAL', 'INGLESIDE', 'MISSION', 'NORTHERN', 'PARK',
#        'RICHMOND', 'SOUTHERN', 'TARAVAL', 'TENDERLOIN'], dtype=object)

# %%
# Create levels for police districts
range(len(pd_districts))
# Out:
# range(0, 10)

# %%
# Create a dictionary mapping police districts to levels
pd_districts_levels = dict(zip(pd_districts, range(len(pd_districts))))
pd_districts_levels
# Out:
# {'BAYVIEW': 0,
#  'CENTRAL': 1,
#  'INGLESIDE': 2,
#  'MISSION': 3,
#  'NORTHERN': 4,
#  'PARK': 5,
#  'RICHMOND': 6,
#  'SOUTHERN': 7,
#  'TARAVAL': 8,
#  'TENDERLOIN': 9}

# %%
# Assign a numerical code to each police district and create a new column
SF['PdDistrictCode'] = SF['PdDistrict'].apply(lambda row: pd_districts_levels[row])

# %%
# Create a scatter plot of crime incidents using longitude and latitude coordinates, with each district represented by a different color
plt.scatter(SF['X'], SF['Y'], c=SF['PdDistrictCode'])
plt.show()

# %%
# Get colors for each police district
from matplotlib import colors
districts = np.unique(SF['PdDistrict'])
print(list(colors.cnames.values())[0:len(districts)])
# Out:
# ['#F0F8FF', '#FAEBD7', '#00FFFF', '#7FFFD4', '#F0FFFF', '#F5F5DC', '#FFE4C4', '#000000', '#FFEBCD', '#0000FF']

# %%
# Create a dictionary mapping police districts to colors
color_dict = dict(zip(districts, list(colors.cnames.values())[0:-1:len(districts)])) 
color_dict
# Out:
# {'BAYVIEW': '#F0F8FF',
#  'CENTRAL': '#8A2BE2',
#  'INGLESIDE': '#00FFFF',
#  'MISSION': '#FF8C00',
#  'NORTHERN': '#FF1493',
#  'PARK': '#F8F8FF',
#  'RICHMOND': '#4B0082',
#  'SOUTHERN': '#FAFAD2',
#  'TARAVAL': '#B0C4DE',
#  'TENDERLOIN': '#9370DB'}

# %%
# Create a folium map centered around the mean latitude and longitude of the crime incidents
map_osm = folium.Map(location=[SF['Y'].mean(), SF['X'].mean()], zoom_start = 12)
# Plot every nth crime incident on the map
plotEvery = 50
obs = list(zip( SF['Y'], SF['X'], SF['PdDistrict'])) 

for el in obs[0:-1:plotEvery]: 
    
    folium.CircleMarker(el[0:2], color=color_dict[el[2]], fill_color=el[2],radius=10).add_to(map_osm)

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# !jupyter nbconvert --to html Crimes.ipynb
# Out:
# [NbConvertApp] Converting notebook Crimes.ipynb to html
# [NbConvertApp] Writing 1253131 bytes to Crimes.html

# %% [markdown]
# <font size='0.5'>&copy; 2017 Cisco and/or its affiliates. All rights reserved. This document is Cisco Public.<font>
